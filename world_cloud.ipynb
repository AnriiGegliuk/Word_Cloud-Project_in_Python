# %% [markdown]
# # My First WordCloud project¶
#
#
# Word Cloud is a data visualization technique used for representing text data in which the size of each word indicates its frequency or importance. Significant textual data points can be highlighted using a word cloud.
#
# This is my first WordCloud project developed using Python.
#
# It is based on Steve Jobs speeach Commencement Address at Stanford 2005 (Excerpt)
#
# https://academyatthelakes.org/wp-content/uploads/2016/02/SteveJobsatStanfordUniversityExcerpts.pdf
#
# Library documentation: https://amueller.github.io/word_cloud/

# %%
# Importing all necessary libraries
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import numpy as np

# %%
# Importing and reading a file
file = open('Steve_Jobs.txt', mode='r', encoding='utf-8').read()

# %%
# Printing how many words are in the file 
print(len(file))
# Out:
# 4767

# %%
# Defining stopwords and printing their length
stopwords = STOPWORDS
print(len(stopwords))
# Out:
# 192

# %%
wc = WordCloud(
    background_color = 'black',
    stopwords = stopwords, 
    normalize_plurals = True,
    collocations = False,
    height = 1000,
    width = 1000
).generate(file)

# %%
# Saving results as PNG
wc.to_file('Steve_Jobs.png')

# %%
# Visualizing results
plt.figure(figsize = (10, 10))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)
